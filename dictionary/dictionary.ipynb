# %%
import pandas as pd
import numpy as np
import json

# %%
data=json.load(open('data.json'))

# %%
df = pd.DataFrame.from_dict(data,orient="index")

# %%
df.head()
# Out:
#                                                                           0   \
# abandoned industrial site  Site that cannot be used for any purpose, bein...
# abandoned vehicle          A vehicle that has been discarded in the envir...
# abiotic factor             Physical, chemical and other non-living enviro...
# access road                Any street or narrow stretch of paved surface ...
# access to the sea          The ability to bring goods to and from a port ...
#
#                              1     2     3     4     5     6     7     8   \
# abandoned industrial site  None  None  None  None  None  None  None  None
# abandoned vehicle          None  None  None  None  None  None  None  None
# abiotic factor             None  None  None  None  None  None  None  None
# access road                None  None  None  None  None  None  None  None
# access to the sea          None  None  None  None  None  None  None  None
#
# ...
